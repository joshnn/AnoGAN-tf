# %% [markdown]
# <a href="https://colab.research.google.com/github/joshnn/AnoGAN-tf/blob/master/Colab_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colab front page for AnoGAN example. See the following link (forked version as of tthis writing).
#
# - Original repo: https://github.com/LeeDoYup/AnoGAN-tf
# - Colab migration: https://github.com/joshnn/AnoGAN-tf

# %%
# %tensorflow_version 1.x
# %cd /content
# !git clone https://github.com/joshnn/AnoGAN-tf
# %cd AnoGAN-tf
# !git pull origin master
# %run download.py mnist celebA
# Out:
# TensorFlow 1.x selected.
# /content
# Cloning into 'AnoGAN-tf'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 169 (delta 8), reused 0 (delta 0), pack-reused 151
# Receiving objects: 100% (169/169), 753.08 KiB | 2.05 MiB/s, done.
# Resolving deltas: 100% (74/74), done.
# /content/AnoGAN-tf
# From https://github.com/joshnn/AnoGAN-tf
#  * branch            master     -> FETCH_HEAD
# Already up to date.
# ./data/img_align_celeba.zip: 44.1kB [00:24, 1.80kB/s]
# http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# ...
# Decompressing  train-images-idx3-ubyte.gz
# http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# ...
# Decompressing  train-labels-idx1-ubyte.gz
# http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# ...
# Decompressing  t10k-images-idx3-ubyte.gz
# http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# ...
# Decompressing  t10k-labels-idx1-ubyte.gz

# %%
# !ls checkpoint
# Out:
# assets	    data	 LICENSE  main.py   ops.py	 README.md  test_data
# checkpoint  download.py  logs	  model.py  __pycache__  samples    utils.py

# %%
# !python main.py --dataset mnist --input_height=28 --output_height=28 --train --train_size=200
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/AnoGAN-tf/ops.py:10: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
#
# WARNING:tensorflow:From /content/AnoGAN-tf/ops.py:11: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/AnoGAN-tf/ops.py:12: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From /content/AnoGAN-tf/ops.py:13: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# ...

# %%
# !ls -l checkpoint/mnist_64_28_28
# Out:
# total 42792
# -rw-r--r-- 1 root root       83 Sep 24 19:51 checkpoint
# -rw-r--r-- 1 root root 43406936 Sep 24 19:51 DCGAN.model-2.data-00000-of-00001
# -rw-r--r-- 1 root root     1389 Sep 24 19:51 DCGAN.model-2.index
# -rw-r--r-- 1 root root   400556 Sep 24 19:51 DCGAN.model-2.meta

# %%
# !ls data/mnist
# Out:
# t10k-images-idx3-ubyte	train-images-idx3-ubyte
# t10k-labels-idx1-ubyte	train-labels-idx1-ubyte

# %%
# !python main.py --dataset mnist --input_height=108 --output_height=28 --output_width=28 --crop --anomaly_test --checkpoint_dir='checkpoint'
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/AnoGAN-tf/ops.py:10: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
#
# WARNING:tensorflow:From /content/AnoGAN-tf/ops.py:11: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/AnoGAN-tf/ops.py:12: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From /content/AnoGAN-tf/ops.py:13: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# ...

# %%
# %run main.py

# %%
# !pip install kora
from kora import console
console.start()  # and click link
# Out:
# ...
# Console URL: https://eu.teleconsole.com/s/3c706132a5f5b08fa8a2a44115838fce035d645d
